# %% [markdown]
# # Analise de dados - Terceira imersão de dados Alura

# %% [markdown]
# ## Resumo
#
# Aqui vamos analisar dados de uma tabela que trás informações sobre células que  foram expostas a modificações genéticas através de experiẽncias com drogas(remédios) e controle, quando precisamos isolar uma certa substância para podermos ter uma melhor precisão dos dados coletados na pesquisa. Na tabela a baixo podemos analiasr o tipo de tratamento que cada célula obteve, o tempo que levou para que a droga fizesse o efeito esperado sobre a célula, a quantidade de dosagem aplicada na célula, a droga utilizada e a porcetagem de RNAs afetados em cada gene de DNA alterado pelos experimentos.

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# ## Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# A classe tratamento é desbalanceada pois esxistem dois tipos de tratamento e um deles é dado a partir de drogas, na qual são 3289, o que acaba causando uma enorme discrepancia nos dados.

# %% [markdown]
# ## Desafio 02: Plotar as 5 últimas linhas da tabela.
#
# ### 5 útimas linhas da tabela plotadas

# %%
dados = pd.Series([23809, 23810, 23811, 23812, 23813])
dados.plot.bar()

# %% [markdown]
# ## Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ## Desafio 04: Quantos tipos de drogas foram investigados.
# ### Tipos de drogas investigadas = 3289

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# d9fcbe12c       1
# 277f1d6f9       1
# 288e0d205       1
# 866e7bc56       1
# c0521523c       1
# Name: droga, Length: 3289, dtype: int64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tempo'].value_counts().plot.line()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 05: Procurar na documentação o método query(pandas).

# %%
dados.query('droga > tratamento')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 9      id_0023f063e  com_droga     48   D2  ... -0.8745 -0.2716  0.0189 -2.0000
# 12     id_0025c5949  com_droga     48   D1  ...  0.8592  0.2429  0.3453  0.3083
# 14     id_002d31e2c  com_droga     72   D1  ... -8.1330 -4.3170 -6.2390  0.9477
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23795  id_ffdd24c81  com_droga     72   D2  ... -1.3750 -0.1953  0.1330 -0.2419
# 23800  id_fff1a3307  com_droga     72   D2  ...  0.3823  0.8707  0.8011  0.4942
# 23803  id_fff485da4  com_droga     48   D1  ... -0.0557  0.6457 -0.4622  0.8154
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
#
# ...

# %% [markdown]
# ## Desafio 06: Colocar uma label no gráfico. (Matplotlib.pyplot).

# %%
dados['tratamento'].value_counts().plot.bar(xlabel = 'Tratamentos', ylabel = 'contagem', title='Somatório de tratamentos utilizadas em experimentos', fontsize = 11, label = 'somatório', legend='true', color = 'purple')

# %% [markdown]
# ## Desafio 07: Renomear as colunas tirando o hífen.

# %%
dados.columns = dados.columns.str.replace('-', '')
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]
